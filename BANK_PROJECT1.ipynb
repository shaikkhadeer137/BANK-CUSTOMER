# %% [markdown]
# <a href="https://colab.research.google.com/github/shaikkhadeer137/BANK-CUSTOMER/blob/main/BANK_PROJECT1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !apt-get install sqlite3
# !pip install pandas
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Suggested packages:
#   sqlite3-doc
# The following NEW packages will be installed:
#   sqlite3
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 769 kB of archives.
# After this operation, 1,874 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 sqlite3 amd64 3.37.2-2ubuntu0.5 [769 kB]
# Fetched 769 kB in 0s (2,393 kB/s)
# Selecting previously unselected package sqlite3.
# (Reading database ... 126374 files and directories currently installed.)
# Preparing to unpack .../sqlite3_3.37.2-2ubuntu0.5_amd64.deb ...
# Unpacking sqlite3 (3.37.2-2ubuntu0.5) ...
# Setting up sqlite3 (3.37.2-2ubuntu0.5) ...
# Processing triggers for man-db (2.10.2-1) ...
# ...

# %%
import sqlite3
import pandas as pd
import os

# %%
conn = sqlite3.connect("my_database.db")

# %%
#define the correct path the database
db_path ="/content/drive/MyDrive/my_database.db"

# %%
db_folder ="/content/drive/MyDrive/sqlite folder"
os.makedirs(db_folder,exist_ok=True)
db_path = os.path.join(db_folder,"my_database.db")

conn =sqlite3.connect(db_path)
cursor=conn.cursor()

print("Database connected at:",db_path)
# Out:
# Database connected at: /content/drive/MyDrive/sqlite folder/my_database.db

# %%
cursor.execute('''
CREATE TABLE BANK_CUSTOMERS ( customer_id INT ,
             	customer_name VARCHAR(20),
             	Address 	VARCHAR(20),
             	state_code  VARCHAR(3) ,
             	Telephone   VARCHAR(10)	);
''')
conn.commit()

# %%
def insert_BANK_CUSTOMERS(customer_id,customer_name,Address,state_code,Telephone):
  cursor.execute("INSERT INTO BANK_CUSTOMERS (customer_id,customer_name,Address,state_code,Telephone) VALUES(?,?,?,?,?)",(customer_id,customer_name,Address,state_code,Telephone))
  conn.commit()

#INSERT
insert_BANK_CUSTOMERS(123001,"Oliver", "225-5, Emeryville", "CA" , "1897614500");
insert_BANK_CUSTOMERS(123002,"George", "194-6,New brighton","MN" , "1897617000");
insert_BANK_CUSTOMERS(123003,"Harry", "2909-5,walnut creek","CA" , "1897617866");
insert_BANK_CUSTOMERS(123004,"Jack", "229-5, Concord",  	"CA" , "1897627999");
insert_BANK_CUSTOMERS(123005,"Jacob", "325-7, Mission Dist","SFO", "1897637000");
insert_BANK_CUSTOMERS(123006,"Noah", "275-9, saint-paul" ,  "MN" , "1897613200");
insert_BANK_CUSTOMERS(123007,"Charlie","125-1,Richfield",   "MN" , "1897617666");
insert_BANK_CUSTOMERS(123008,"Robin","3005-1,Heathrow", 	"NY" , "1897614000");

# %%
pip install tabulate

# %%
from tabulate import tabulate

# fetch the data
cursor.execute("SELECT DISTINCT * FROM BANK_CUSTOMERS")
rows = cursor.fetchall()

#get the columns names
column_names = [desc[0] for desc in cursor.description]

#print in tabular format
print(tabulate(rows,headers=column_names,tablefmt="grid"))
# Out:
# +---------------+-----------------+---------------------+--------------+-------------+
# |   customer_id | customer_name   | Address             | state_code   |   Telephone |
# +===============+=================+=====================+==============+=============+
# |        123001 | Oliver          | 225-5, Emeryville   | CA           |  1897614500 |
# +---------------+-----------------+---------------------+--------------+-------------+
# |        123002 | George          | 194-6,New brighton  | MN           |  1897617000 |
# +---------------+-----------------+---------------------+--------------+-------------+
# |        123003 | Harry           | 2909-5,walnut creek | CA           |  1897617866 |
# +---------------+-----------------+---------------------+--------------+-------------+
# |        123004 | Jack            | 229-5, Concord      | CA           |  1897627999 |
# +---------------+-----------------+---------------------+--------------+-------------+
# ...

# %% [markdown]
# Bank Account Table

# %%
cursor.execute('''
CREATE TABLE BANK_CUSTOMERS_ACCOUNTS ( Customer_id INT,
	                Account_Number VARCHAR(19),
		     Account_type VARCHAR(25),
		     Balance_amount INT ,
			Account_status VARCHAR(10), Relation_ship varchar(1) ) ;
''')
conn.commit()

# %%
from pickle import NONE
def insert_bank_customers_accounts(Customer_id,Account_Number,Account_type,Balance_amount,Account_status,Relation_ship):
  cursor.execute("insert into BANK_CUSTOMERS_ACCOUNTS(Customer_id,Account_Number,Account_type,Balance_amount,Account_status,Relation_ship) VALUES(?,?,?,?,?,?)",(Customer_id,Account_Number,Account_type,Balance_amount,Account_status,Relation_ship))
  conn.commit()
insert_bank_customers_accounts (123001, "4000-1956-3456",  "SAVINGS"            , 200000 ,"ACTIVE","P");
insert_bank_customers_accounts (123001, "5000-1700-3456",  "RECURRING DEPOSITS" ,9400000 ,"ACTIVE","S");
insert_bank_customers_accounts (123002, "4000-1956-2001",  "SAVINGS"            , 400000 ,"ACTIVE","P");
insert_bank_customers_accounts (123002, "5000-1700-5001",  "RECURRING DEPOSITS" ,7500000 ,"ACTIVE","S");
insert_bank_customers_accounts (123003, "4000-1956-2900",  "SAVINGS"            ,750000,"INACTIVE","P");
insert_bank_customers_accounts (123004, "5000-1700-6091",  "RECURRING DEPOSITS" ,7500000 ,"ACTIVE","S");
insert_bank_customers_accounts (123004, "4000-1956-3401",  "SAVINGS"            , 655000 ,"ACTIVE","P");
insert_bank_customers_accounts (123005, "4000-1956-5102",  "SAVINGS"            , 300000 ,"ACTIVE","P");
insert_bank_customers_accounts (123006, "4000-1956-5698",  "SAVINGS"            , 455000 ,"ACTIVE" ,"P");
insert_bank_customers_accounts (123007, "5000-1700-9800",  "SAVINGS"            , 355000 ,"ACTIVE" ,"P");
insert_bank_customers_accounts (123007, "4000-1956-9977",  "RECURRING DEPOSITS" , 7025000,"ACTIVE" ,"S");
insert_bank_customers_accounts (123007, "9000-1700-7777-4321",  "CREDITCARD"    ,0      ,"INACTIVE","P");
insert_bank_customers_accounts (123008, "5000-1700-7755",  "SAVINGS"            ,NONE   ,"INACTIVE","P");

# %%
from tabulate import tabulate

cursor.execute("SELECT DISTINCT * FROM BANK_CUSTOMERS_ACCOUNTS")
rows = cursor.fetchall()
column_names = [desc[0] for desc in cursor.description]

print(tabulate(rows,headers=column_names,tablefmt="grid"))
# Out:
# +---------------+---------------------+--------------------+------------------+------------------+-----------------+
# |   Customer_id | Account_Number      | Account_type       | Balance_amount   | Account_status   | Relation_ship   |
# +===============+=====================+====================+==================+==================+=================+
# |        123001 | 4000-1956-3456      | SAVINGS            | 200000           | ACTIVE           | P               |
# +---------------+---------------------+--------------------+------------------+------------------+-----------------+
# |        123001 | 5000-1700-3456      | RECURRING DEPOSITS | 9400000          | ACTIVE           | S               |
# +---------------+---------------------+--------------------+------------------+------------------+-----------------+
# |        123002 | 4000-1956-2001      | SAVINGS            | 400000           | ACTIVE           | P               |
# ...

# %% [markdown]
# BANK ACCOUNT DETAIL TABLE

# %%
cursor.execute('''
CREATE TABLE BANK_ACCOUNTS_DETAILS (Customer_id INT,
                             	Account_Number VARCHAR(19),
                              	Account_type VARCHAR(25),
                           	    Balance_amount INT,
                               	Account_status VARCHAR(10),
                               	Relationship_type varchar(1) ) ;
''')
conn.commit()

# %%
def insert_bank_accounts_details(Customer_id,Account_Number,Account_type,Balance_amount,Account_status,Relationship_type):
  cursor.execute("insert into BANK_ACCOUNTS_DETAILS(Customer_id,Account_Number,Account_type,Balance_amount,Account_status,Relationship_type) VALUES (?,?,?,?,?,?)",(Customer_id,Account_Number,Account_type,Balance_amount,Account_status,Relationship_type))
  conn.commit()
insert_bank_accounts_details (123001, "4000-1956-3456",  "SAVINGS" , 200000 ,"ACTIVE","P");
insert_bank_accounts_details (123001, "5000-1700-3456", "RECURRING DEPOSITS" ,9400000 ,"ACTIVE","S");
insert_bank_accounts_details (123002, "4000-1956-2001",  "SAVINGS", 400000 ,"ACTIVE","P");
insert_bank_accounts_details (123002, "5000-1700-5001",  "RECURRING DEPOSITS" ,7500000 ,"ACTIVE","S");
insert_bank_accounts_details (123003, "4000-1956-2900",  "SAVINGS" ,750000,"INACTIVE","P");
insert_bank_accounts_details (123004, "5000-1700-6091", "RECURRING DEPOSITS" ,7500000 ,"ACTIVE","S");
insert_bank_accounts_details (123004, "4000-1956-3401",  "SAVINGS" , 655000 ,"ACTIVE","P");
insert_bank_accounts_details (123005, "4000-1956-5102",  "SAVINGS" , 300000 ,"ACTIVE","P");
insert_bank_accounts_details (123006, "4000-1956-5698",  "SAVINGS" , 455000 ,"ACTIVE" ,"P");
insert_bank_accounts_details (123007, "5000-1700-9800",  "SAVINGS" , 355000 ,"ACTIVE" ,"P");
insert_bank_accounts_details (123007, "4000-1956-9977",  "RECURRING DEPOSITS" , 7025000,"ACTIVE" ,"S");
insert_bank_accounts_details (123007, "9000-1700-7777-4321",  "Credit Card"	,0  ,"INACTIVE", "P");
insert_bank_accounts_details (123007, '5900-1900-9877-5543', "Add-on Credit Card" ,   0   ,"ACTIVE", "S");
insert_bank_accounts_details (123008, "5000-1700-7755",  "SAVINGS"   	,0   	,"INACTIVE","P");
insert_bank_accounts_details (123006, '5800-1700-9800-7755', "Credit Card"   ,0   	,"ACTIVE", "P");
insert_bank_accounts_details (123006, '5890-1970-7706-8912', "Add-on Credit Card"   ,0   	,"ACTIVE", "S");

# %%
from tabulate import tabulate

cursor.execute("SELECT DISTINCT * FROM BANK_ACCOUNTS_DETAILS")
rows = cursor.fetchall()
column_names = [desc[0] for desc in cursor.description]

print(tabulate(rows,headers=column_names,tablefmt="grid"))
# Out:
# +---------------+---------------------+--------------------+------------------+------------------+---------------------+
# |   Customer_id | Account_Number      | Account_type       |   Balance_amount | Account_status   | Relationship_type   |
# +===============+=====================+====================+==================+==================+=====================+
# |        123001 | 4000-1956-3456      | SAVINGS            |           200000 | ACTIVE           | P                   |
# +---------------+---------------------+--------------------+------------------+------------------+---------------------+
# |        123001 | 5000-1700-3456      | RECURRING DEPOSITS |          9400000 | ACTIVE           | S                   |
# +---------------+---------------------+--------------------+------------------+------------------+---------------------+
# |        123002 | 4000-1956-2001      | SAVINGS            |           400000 | ACTIVE           | P                   |
# ...

# %% [markdown]
# Bank_Account_Relationship_Details Table

# %%
cursor.execute('''
CREATE TABLE BANK_ACCOUNTS_RELATIONSHIP_DETAILS
                             	( Customer_id INT,
								Account_Number VARCHAR(19),
                            	Account_type VARCHAR(25),
                             	Linking_Account_Number VARCHAR(19));
''')
conn.commit()

# %%
def insert_bank_accounts_relationship_details(Customer_id,Account_Number,Account_type,Linking_Account_Number):
  cursor.execute("insert into BANK_ACCOUNTS_RELATIONSHIP_DETAILS(Customer_id,Account_Number,Account_type,Linking_Account_Number) VALUES (?,?,?,?)",(Customer_id,Account_Number,Account_type,Linking_Account_Number))
  conn.commit()
insert_bank_accounts_relationship_details (123001, "4000-1956-3456",  "SAVINGS" , "");
insert_bank_accounts_relationship_details (123001, "5000-1700-3456",  "RECURRING DEPOSITS" , "4000-1956-3456");
insert_bank_accounts_relationship_details (123002, "4000-1956-2001",  "SAVINGS" , "" );
insert_bank_accounts_relationship_details (123002, "5000-1700-5001",  "RECURRING DEPOSITS" , "4000-1956-2001" );
insert_bank_accounts_relationship_details (123003, "4000-1956-2900",  "SAVINGS" , "" );
insert_bank_accounts_relationship_details (123004, "5000-1700-6091",  "RECURRING DEPOSITS" , "4000-1956-2900" );
insert_bank_accounts_relationship_details (123004, "5000-1700-7791",  "RECURRING DEPOSITS" , "4000-1956-2900" );
insert_bank_accounts_relationship_details (123007, "5000-1700-9800",  "SAVINGS" , "" );
insert_bank_accounts_relationship_details (123007, "4000-1956-9977",  "RECURRING DEPOSITS" , "5000-1700-9800" );
insert_bank_accounts_relationship_details (NONE, "9000-1700-7777-4321",  "Credit Card" , "5000-1700-9800" );
insert_bank_accounts_relationship_details (NONE, '5900-1900-9877-5543', 'Add-on Credit Card', '9000-1700-7777-4321' );
insert_bank_accounts_relationship_details (NONE, '5800-1700-9800-7755', 'Credit Card', '4000-1956-5698' );
insert_bank_accounts_relationship_details (NONE, '5890-1970-7706-8912', 'Add-on Credit Card', '5800-1700-9800-7755' );

# %%
from tabulate import tabulate

cursor.execute("SELECT DISTINCT * FROM BANK_ACCOUNTS_RELATIONSHIP_DETAILS")
rows = cursor.fetchall()
column_names = [desc[0] for desc in cursor.description]

print(tabulate(rows,headers=column_names,tablefmt="grid"))
# Out:
# +---------------+---------------------+--------------------+--------------------------+
# | Customer_id   | Account_Number      | Account_type       | Linking_Account_Number   |
# +===============+=====================+====================+==========================+
# | 123001        | 4000-1956-3456      | SAVINGS            |                          |
# +---------------+---------------------+--------------------+--------------------------+
# | 123001        | 5000-1700-3456      | RECURRING DEPOSITS | 4000-1956-3456           |
# +---------------+---------------------+--------------------+--------------------------+
# | 123002        | 4000-1956-2001      | SAVINGS            |                          |
# +---------------+---------------------+--------------------+--------------------------+
# | 123002        | 5000-1700-5001      | RECURRING DEPOSITS | 4000-1956-2001           |
# +---------------+---------------------+--------------------+--------------------------+
# ...

# %% [markdown]
# BANK_ACCOUNT_TRANSACTION TABLE

# %%
cursor.execute('''
CREATE TABLE BANK_ACCOUNTS_TRANSACTION (
              	Account_Number VARCHAR(19),
              	Transaction_amount Decimal(18,2) ,
              	Transcation_channel VARCHAR(18) ,
             	Province varchar(3) ,
             	Transaction_Date Date) ;
''')
conn.commit()

# %%
def insert_bank_accounts_transaction(Account_Number,Transaction_amount,Transcation_channel,Province,Transaction_Date):
  cursor.execute("insert into BANK_ACCOUNTS_TRANSACTION(Account_Number,Transaction_amount,Transcation_channel,Province,Transaction_Date) VALUES (?,?,?,?,?)",(Account_Number,Transaction_amount,Transcation_channel,Province,Transaction_Date))
  conn.commit()
insert_bank_accounts_transaction ( "4000-1956-3456",  -2000, "ATM withdrawl" , "CA", "2020-01-13");
insert_bank_accounts_transaction ( "4000-1956-2001",  -4000, "POS-Walmart"   , "MN", "2020-02-14");
insert_bank_accounts_transaction ( "4000-1956-2001",  -1600, "UPI transfer"  , "MN", "2020-01-19");
insert_bank_accounts_transaction ( "4000-1956-2001",  -6000, "Bankers cheque", "CA", "2020-03-23");
insert_bank_accounts_transaction ( "4000-1956-2001",  -3000, "Net banking"   , "CA", "2020-04-24");
insert_bank_accounts_transaction ( "4000-1956-2001",  23000, "cheque deposit", "MN", "2020-03-15");
insert_bank_accounts_transaction ( "5000-1700-6091",  40000, "ECS transfer"  , "NY", "2020-02-19");
insert_bank_accounts_transaction ( "5000-1700-7791",  40000, "ECS transfer"  , "NY", "2020-02-19");
insert_bank_accounts_transaction ( "4000-1956-3401",   8000, "Cash Deposit"  , "NY", "2020-01-19");
insert_bank_accounts_transaction ( "4000-1956-5102",  -6500, "ATM withdrawal" , "NY", "2020-03-14");
insert_bank_accounts_transaction ( "4000-1956-5698",  -9000, "Cash Deposit"  , "NY", "2020-03-27");
insert_bank_accounts_transaction ( "4000-1956-9977",  50000, "ECS transfer"  , "NY", "2020-01-16");
insert_bank_accounts_transaction ( "9000-1700-7777-4321",  -5000, "POS-Walmart", "NY", "2020-02-17");
insert_bank_accounts_transaction ( "9000-1700-7777-4321",  -8000, "Shopping Cart", "MN", "2020-03-13");
insert_bank_accounts_transaction ( "9000-1700-7777-4321",  -2500, "Shopping Cart", "MN", "2020-04-21");
insert_bank_accounts_transaction ( "5800-1700-9800-7755", -9000, "POS-Walmart","MN", "2020-04-13");
insert_bank_accounts_transaction ( '5890-1970-7706-8912', -11000, "Shopping Cart" , "NY" , "2020-03-12") ;
insert_bank_accounts_transaction ('4000-1956-9977' ,    10000.00     ,'ECS transfer',     'MN' ,    '2020-02-16') ;
insert_bank_accounts_transaction ('4000-1956-9977' ,    40000.00     ,'ECS transfer',     'MN' ,    '2020-03-18' ) ;
insert_bank_accounts_transaction ('4000-1956-9977' ,    60000.00     ,'ECS transfer',     'MN' ,    '2020-04-18' ) ;
insert_bank_accounts_transaction ('4000-1956-9977' ,    20000.00     ,'ECS transfer',     'MN' ,    '2020-03-20' ) ;

# %%
from tabulate import tabulate

cursor.execute("SELECT DISTINCT * FROM BANK_ACCOUNTS_TRANSACTION")
rows = cursor.fetchall()
column_names = [desc[0] for desc in cursor.description]

print(tabulate(rows,headers=column_names,tablefmt="grid"))
# Out:
# +---------------------+----------------------+-----------------------+------------+--------------------+
# | Account_Number      |   Transaction_amount | Transcation_channel   | Province   | Transaction_Date   |
# +=====================+======================+=======================+============+====================+
# | 4000-1956-3456      |                -2000 | ATM withdrawl         | CA         | 2020-01-13         |
# +---------------------+----------------------+-----------------------+------------+--------------------+
# | 4000-1956-2001      |                -4000 | POS-Walmart           | MN         | 2020-02-14         |
# +---------------------+----------------------+-----------------------+------------+--------------------+
# | 4000-1956-2001      |                -1600 | UPI transfer          | MN         | 2020-01-19         |
# +---------------------+----------------------+-----------------------+------------+--------------------+
# ...

# %% [markdown]
# BANK_CUSTOMER_MESSAGES TABLE

# %%
cursor.execute('''
CREATE TABLE BANK_CUSTOMERS_MESSAGES (
              	Event VARCHAR(24),
              	Customer_message VARCHAR(75),
              	Notice_delivery_mode VARCHAR(15)) ;
''')
conn.commit()

# %%
def insert_bank_customers_messages(Event,Customer_message,Notice_delivery_mode):
  cursor.execute("insert into BANK_CUSTOMERS_MESSAGES(Event,Customer_message,Notice_delivery_mode) VALUES (?,?,?)",(Event,Customer_message,Notice_delivery_mode))
  conn.commit()

insert_bank_customers_messages ( "Adhoc", "All Banks are closed due to announcement of National strike", "mobile" ) ;
insert_bank_customers_messages ( "Transaction Limit", "Only limited withdrawals per card are allowed from ATM machines", "mobile" );

# %%
from tabulate import tabulate

cursor.execute("SELECT DISTINCT * FROM BANK_CUSTOMERS_MESSAGES")
rows = cursor.fetchall()
column_names = [desc[0] for desc in cursor.description]

print(tabulate(rows,headers=column_names,tablefmt="grid"))
# Out:
# +-------------------+-----------------------------------------------------------------+------------------------+
# | Event             | Customer_message                                                | Notice_delivery_mode   |
# +===================+=================================================================+========================+
# | Adhoc             | All Banks are closed due to announcement of National strike     | mobile                 |
# +-------------------+-----------------------------------------------------------------+------------------------+
# | Transaction Limit | Only limited withdrawals per card are allowed from ATM machines | mobile                 |
# +-------------------+-----------------------------------------------------------------+------------------------+

# %% [markdown]
# Bank interest rate table

# %%
cursor.execute('''
CREATE TABLE BANK_INTERESTS_RATE(
            	account_type varchar(24),
              	interest_rate decimal(4,2),
            	month varchar(2),
            	year  varchar(4)
             	);
''')
conn.commit()

# %%
def insert_bank_interests_rate(account_type,interest_rate,month,year):
  cursor.execute("insert into BANK_INTERESTS_RATE(account_type,interest_rate,month,year) VALUES (?,?,?,?)",(account_type,interest_rate,month,year))
  conn.commit()
insert_bank_interests_rate ( "SAVINGS" , 0.04 , '02' , '2020' );
insert_bank_interests_rate ( "RECURRING DEPOSITS" , 0.07, '02' , '2020' );
insert_bank_interests_rate ( "PRIVILEGED_INTEREST_RATE" , 0.08 , '02' , '2020' )

# %%
from tabulate import tabulate

cursor.execute("SELECT DISTINCT * FROM BANK_INTERESTS_RATE")
rows = cursor.fetchall()
column_names = [desc[0] for desc in cursor.description]

print(tabulate(rows,headers=column_names,tablefmt="grid"))
# Out:
# +--------------------------+-----------------+---------+--------+
# | account_type             |   interest_rate |   month |   year |
# +==========================+=================+=========+========+
# | SAVINGS                  |            0.04 |      02 |   2020 |
# +--------------------------+-----------------+---------+--------+
# | RECURRING DEPOSITS       |            0.07 |      02 |   2020 |
# +--------------------------+-----------------+---------+--------+
# | PRIVILEGED_INTEREST_RATE |            0.08 |      02 |   2020 |
# +--------------------------+-----------------+---------+--------+

# %% [markdown]
# 1.Print customer Id, customer name and average account_balance maintained by each customer for all of his/her accounts in the bank.(8 Rows)

# %%
query = """
SELECT
    c.customer_id,
    c.customer_name,
    AVG(a.Balance_amount) AS average_account_balance
FROM BANK_CUSTOMERS c
JOIN BANK_ACCOUNTS_DETAILS a ON c.customer_id = a.Customer_id
GROUP BY c.customer_id, c.customer_name
ORDER BY c.customer_id;
"""
cursor.execute(query)
rows = cursor.fetchall()
column_names = [desc[0] for desc in cursor.description]
from tabulate import tabulate
print(tabulate(rows, headers=column_names, tablefmt="grid"))
# Out:
# +---------------+-----------------+---------------------------+
# |   customer_id | customer_name   |   average_account_balance |
# +===============+=================+===========================+
# |        123001 | Oliver          |                4.8e+06    |
# +---------------+-----------------+---------------------------+
# |        123002 | George          |                3.95e+06   |
# +---------------+-----------------+---------------------------+
# |        123003 | Harry           |           750000          |
# +---------------+-----------------+---------------------------+
# |        123004 | Jack            |                4.0775e+06 |
# +---------------+-----------------+---------------------------+
# |        123005 | Jacob           |           300000          |
# +---------------+-----------------+---------------------------+
# |        123006 | Noah            |           151667          |
# +---------------+-----------------+---------------------------+
# ...

# %% [markdown]
# QUESTION 2: Print customer_id , account_number and balance_amount , condition that if balance_amount is nil then assign transaction_amount for account_type = "Credit Card"(4 Rows)

# %%
query = """
  SELECT
    a.Customer_id,a.Account_Number,
    COALESCE(NULLIF(a.Balance_amount, 0), t.Transaction_amount) AS Final_Balance
FROM BANK_ACCOUNTS_DETAILS a
LEFT JOIN BANK_ACCOUNTS_TRANSACTION t ON a.Account_Number = t.Account_Number
WHERE a.Account_type = 'Credit Card'
LIMIT 4;

"""
result = pd.read_sql_query(query, conn)
print(tabulate(result, headers='keys', tablefmt='psql'))
# Out:
# +----+---------------+---------------------+-----------------+
# |    |   Customer_id | Account_Number      |   Final_Balance |
# |----+---------------+---------------------+-----------------|
# |  0 |        123007 | 9000-1700-7777-4321 |           -8000 |
# |  1 |        123007 | 9000-1700-7777-4321 |           -5000 |
# |  2 |        123007 | 9000-1700-7777-4321 |           -2500 |
# |  3 |        123006 | 5800-1700-9800-7755 |           -9000 |
# +----+---------------+---------------------+-----------------+

# %% [markdown]
# QUESTION 3: Print account_number and balance_amount , transaction_amount,Transaction_Date from Bank_Account_Details and bank_account_transaction for all the transactions occurred during march,2020 and april, 2020(12 Rows)

# %%
query=('''
SELECT DISTINCT a.Account_Number,a.Balance_amount,
       t.Transaction_amount,t.Transaction_Date
FROM BANK_ACCOUNTS_DETAILS a
LEFT JOIN BANK_ACCOUNTS_TRANSACTION t ON a.Account_Number = t.Account_Number
WHERE T.Transaction_date BETWEEN '2020-03-01' AND '2020-04-31'
LIMIT 12;
''')

result=pd.read_sql_query(query,conn)
print(tabulate(result,headers='keys',tablefmt='grid'))
# Out:
# +----+---------------------+------------------+----------------------+--------------------+
# |    | Account_Number      |   Balance_amount |   Transaction_amount | Transaction_Date   |
# +====+=====================+==================+======================+====================+
# |  0 | 4000-1956-2001      |           400000 |                -6000 | 2020-03-23         |
# +----+---------------------+------------------+----------------------+--------------------+
# |  1 | 4000-1956-2001      |           400000 |                -3000 | 2020-04-24         |
# +----+---------------------+------------------+----------------------+--------------------+
# |  2 | 4000-1956-2001      |           400000 |                23000 | 2020-03-15         |
# +----+---------------------+------------------+----------------------+--------------------+
# |  3 | 4000-1956-5102      |           300000 |                -6500 | 2020-03-14         |
# ...

# %% [markdown]
# QUESTION 4: Print all of the customer id, account number, balance_amount, transaction_amount , Transaction_Date from bank_customer, Bank_Account_Details and bank_account_transaction tables where excluding all of their transactions in march, 2020 month (22 Rows)

# %%
query = """
SELECT
    b.account_number,
    b.balance_amount,
    t.Transaction_amount,
    t.Transaction_Date
FROM
    BANK_ACCOUNTS_DETAILS b
JOIN
    BANK_ACCOUNTS_TRANSACTION t ON b.account_number = t.account_number
WHERE
    t.Transaction_Date BETWEEN '2020-03-01' AND '2020-04-30';
"""
cursor.execute(query)
rows = cursor.fetchall()
column_names = [desc[0] for desc in cursor.description]
from tabulate import tabulate
print(tabulate(rows, headers=column_names, tablefmt="grid"))
# Out:
# +---------------------+------------------+----------------------+--------------------+
# | Account_Number      |   Balance_amount |   Transaction_amount | Transaction_Date   |
# +=====================+==================+======================+====================+
# | 4000-1956-2001      |           400000 |                -6000 | 2020-03-23         |
# +---------------------+------------------+----------------------+--------------------+
# | 4000-1956-2001      |           400000 |                -3000 | 2020-04-24         |
# +---------------------+------------------+----------------------+--------------------+
# | 4000-1956-2001      |           400000 |                23000 | 2020-03-15         |
# +---------------------+------------------+----------------------+--------------------+
# | 4000-1956-5102      |           300000 |                -6500 | 2020-03-14         |
# +---------------------+------------------+----------------------+--------------------+
# ...

# %% [markdown]
# Question 5: Print only the customer id, account_number, balance_amount,transaction_amount ,transaction_date who did transactions during the first quarter. Do not display the accounts if they have not done any transactions in the first quarter.(16 Rows)

# %%
query=('''
SELECT
    c.customer_id,
    a.Account_Number,a.Balance_amount,
    t.Transaction_amount,t.Transaction_Date
FROM BANK_CUSTOMERS AS c
INNER JOIN BANK_ACCOUNTS_DETAILS AS a ON c.customer_id = a.customer_id
INNER JOIN BANK_ACCOUNTS_TRANSACTION AS t ON a.Account_Number = t.Account_Number
WHERE t.Transaction_Date BETWEEN '2020-01-01' AND '2020-03-31'
LIMIT 16;
''')

result=pd.read_sql_query(query,conn)
print(tabulate(result,headers='keys',tablefmt='grid'))
# Out:
# +----+---------------+---------------------+------------------+----------------------+--------------------+
# |    |   customer_id | Account_Number      |   Balance_amount |   Transaction_amount | Transaction_Date   |
# +====+===============+=====================+==================+======================+====================+
# |  0 |        123001 | 4000-1956-3456      |           200000 |                -2000 | 2020-01-13         |
# +----+---------------+---------------------+------------------+----------------------+--------------------+
# |  1 |        123002 | 4000-1956-2001      |           400000 |                -4000 | 2020-02-14         |
# +----+---------------+---------------------+------------------+----------------------+--------------------+
# |  2 |        123002 | 4000-1956-2001      |           400000 |                -1600 | 2020-01-19         |
# +----+---------------+---------------------+------------------+----------------------+--------------------+
# ...

# %% [markdown]
# Question 6:
# Print account_number, Event and Customer_message from BANK_CUSTOMER_MESSAGES and Bank_Account_Details to display an “Adhoc" Event for all customers who have “SAVINGS" account_type account.(8 Rows)

# %%
query=('''
  SELECT
    a.Account_Number,
    m.Event,m.Customer_message
  FROM BANK_ACCOUNTS_DETAILS a
  CROSS JOIN BANK_CUSTOMER_MESSAGES m ON m.Event = 'Adhoc'
  WHERE a.Account_type = 'SAVINGS'
  LIMIT 8;
''')

result=pd.read_sql_query(query,conn)
print(tabulate(result,headers='keys',tablefmt='grid'))
# Out:
# +----+------------------+---------+-------------------------------------------------------------+
# |    | Account_Number   | Event   | Customer_message                                            |
# +====+==================+=========+=============================================================+
# |  0 | 4000-1956-3456   | Adhoc   | All Banks are closed due to announcement of National strike |
# +----+------------------+---------+-------------------------------------------------------------+
# |  1 | 4000-1956-2001   | Adhoc   | All Banks are closed due to announcement of National strike |
# +----+------------------+---------+-------------------------------------------------------------+
# |  2 | 4000-1956-2900   | Adhoc   | All Banks are closed due to announcement of National strike |
# +----+------------------+---------+-------------------------------------------------------------+
# |  3 | 4000-1956-3401   | Adhoc   | All Banks are closed due to announcement of National strike |
# ...

# %% [markdown]
# Question 7:
# Print all Customer_id, Account_Number, Account_type, and display deducted balance_amount by subtracting only negative transaction_amounts for Relationship_type ="P" ( P - means Primary , S - means Secondary ) .(27 Rows)

# %%
query=('''
  SELECT
    a.Customer_id,a.Account_Number,a.Account_type,-- a.Balance_amount,t.Transaction_amount,a.Relationship_type,
    ((a.Balance_amount) + (t.Transaction_amount)) AS Deducted_Balance_Amount
  FROM BANK_ACCOUNTS_DETAILS a
  LEFT JOIN BANK_ACCOUNTS_TRANSACTION t ON a.Account_Number = t.Account_Number
  WHERE a.Relationship_type ='P' AND t.Transaction_amount < 0
  LIMIT 27;
''')

result=pd.read_sql_query(query,conn)
print(tabulate(result,headers='keys',tablefmt='grid'))
# Out:
# +----+---------------+---------------------+----------------+---------------------------+
# |    |   Customer_id | Account_Number      | Account_type   |   Deducted_Balance_Amount |
# +====+===============+=====================+================+===========================+
# |  0 |        123001 | 4000-1956-3456      | SAVINGS        |                    198000 |
# +----+---------------+---------------------+----------------+---------------------------+
# |  1 |        123002 | 4000-1956-2001      | SAVINGS        |                    394000 |
# +----+---------------+---------------------+----------------+---------------------------+
# |  2 |        123002 | 4000-1956-2001      | SAVINGS        |                    396000 |
# +----+---------------+---------------------+----------------+---------------------------+
# |  3 |        123002 | 4000-1956-2001      | SAVINGS        |                    397000 |
# ...

# %% [markdown]
# Question 8:
# a) Display records of All Accounts , their Account_types, the transaction amount.

# %%
query=('''
  SELECT DISTINCT a.Account_Number,a.Account_type,
         t.Transaction_amount
  FROM BANK_ACCOUNTS_DETAILS a
  LEFT JOIN BANK_ACCOUNTS_TRANSACTION t ON a.Account_Number = t.Account_Number;
''')


result=pd.read_sql_query(query,conn)
print(tabulate(result,headers='keys',tablefmt='grid'))
# Out:
# +----+---------------------+--------------------+----------------------+
# |    | Account_Number      | Account_type       |   Transaction_amount |
# +====+=====================+====================+======================+
# |  0 | 4000-1956-3456      | SAVINGS            |                -2000 |
# +----+---------------------+--------------------+----------------------+
# |  1 | 5000-1700-3456      | RECURRING DEPOSITS |                  nan |
# +----+---------------------+--------------------+----------------------+
# |  2 | 4000-1956-2001      | SAVINGS            |                -6000 |
# +----+---------------------+--------------------+----------------------+
# |  3 | 4000-1956-2001      | SAVINGS            |                -4000 |
# +----+---------------------+--------------------+----------------------+
# |  4 | 4000-1956-2001      | SAVINGS            |                -3000 |
# +----+---------------------+--------------------+----------------------+
# ...

# %% [markdown]
# b) Along with first step, Display other columns with corresponding linking account number, account types (15 Rows)

# %%
query=('''
  SELECT a.Account_Number,a.Account_type,
         t.Transaction_amount,
         r.Customer_id,r.Linking_Account_Number,r.Account_type AS Acc_Type
  FROM BANK_ACCOUNTS_DETAILS a
  LEFT JOIN BANK_ACCOUNTS_TRANSACTION t ON a.Account_Number = t.Account_Number
  LEFT JOIN BANK_ACCOUNTS_RELATIONSHIP_DETAILS r ON r.Linking_Account_Number = a.Account_Number
  LIMIT 15;
''')

result=pd.read_sql_query(query,conn)
print(tabulate(result,headers='keys',tablefmt='grid'))
# Out:
# +----+------------------+--------------------+----------------------+---------------+--------------------------+--------------------+
# |    | Account_Number   | Account_type       |   Transaction_amount | Customer_id   | Linking_Account_Number   | Acc_Type           |
# +====+==================+====================+======================+===============+==========================+====================+
# |  0 | 4000-1956-3456   | SAVINGS            |                -2000 | 123001        | 4000-1956-3456           | RECURRING DEPOSITS |
# +----+------------------+--------------------+----------------------+---------------+--------------------------+--------------------+
# |  1 | 5000-1700-3456   | RECURRING DEPOSITS |                  nan |               |                          |                    |
# +----+------------------+--------------------+----------------------+---------------+--------------------------+--------------------+
# ...

# %% [markdown]
# Question 9:
# a) Display records of All Accounts , their Account_types, the transaction amount.
# b) Along with first step, Display other columns with corresponding linking account number, account types
# c) After retrieving all records of accounts and their linked accounts, display the transaction amount of accounts appeared in another column.(26 Rows)

# %%
query = ('''
  SELECT DISTINCT
         a.Account_Number,a.Account_type,
         t.Transaction_amount,
         r.Linking_Account_Number,r.Account_type AS Acc_Type,
         tr.Transaction_amount AS Amount
  FROM BANK_ACCOUNTS_DETAILS a
  LEFT JOIN BANK_ACCOUNTS_TRANSACTION t ON a.Account_Number = t.Account_Number
  LEFT JOIN BANK_ACCOUNTS_RELATIONSHIP_DETAILS r ON a.Account_Number = r.Account_Number
  LEFT JOIN BANK_ACCOUNTS_TRANSACTION tr ON r.Linking_Account_Number = tr.Account_Number
  LIMIT 26;
''')

result=pd.read_sql_query(query,conn)
print(tabulate(result,headers='keys',tablefmt='grid'))
# Out:
# +----+---------------------+--------------------+----------------------+--------------------------+--------------------+----------+
# |    | Account_Number      | Account_type       |   Transaction_amount | Linking_Account_Number   | Acc_Type           |   Amount |
# +====+=====================+====================+======================+==========================+====================+==========+
# |  0 | 4000-1956-3456      | SAVINGS            |                -2000 |                          | SAVINGS            |      nan |
# +----+---------------------+--------------------+----------------------+--------------------------+--------------------+----------+
# |  1 | 5000-1700-3456      | RECURRING DEPOSITS |                  nan | 4000-1956-3456           | RECURRING DEPOSITS |    -2000 |
# +----+---------------------+--------------------+----------------------+--------------------------+--------------------+----------+
# ...

# %% [markdown]
# Question 10:
# Display all saving account holders have “Add-on Credit Cards" and “Credit cards" (3 Rows

# %%
query=('''
  SELECT
    c.Customer_id, c.Customer_name
  FROM BANK_CUSTOMERS c
  JOIN BANK_ACCOUNTS_DETAILS a ON c.Customer_id = a.Customer_id -- AND a.Account_type = 'SAVINGS'
  JOIN BANK_ACCOUNTS_DETAILS ac ON c.Customer_id = ac.Customer_id -- AND ac.Account_type = 'Add-on Credit Card'
  JOIN BANK_ACCOUNTS_DETAILS acc ON c.Customer_id = acc.Customer_id -- AND acc.Account_type = 'Credit Card'
  WHERE a.Account_type = 'SAVINGS' AND ac.Account_type = 'Add-on Credit Card' AND acc.Account_type = 'Credit Card'
  GROUP BY c.Customer_id,c.Customer_name ;
  ''')
result=pd.read_sql_query(query,conn)
print(tabulate(result,headers='keys',tablefmt='grid'))
# Out:
# +----+---------------+-----------------+
# |    |   customer_id | customer_name   |
# +====+===============+=================+
# |  0 |        123006 | Noah            |
# +----+---------------+-----------------+
# |  1 |        123007 | Charlie         |
# +----+---------------+-----------------+

# %% [markdown]
# Question 11:
# Display records of “SAVINGS” account linked with “Credit cards" account_type and its credit
# aggregate sum of transaction amount. (1 Row)
# Ref: Check linking relationship in bank_transaction_relationship_details.
# Check transaction_amount in bank_account_transaction.

# %%
query=('''
  SELECT r.Account_Number,r.Account_type AS Account,
         re.Account_type, re.Linking_Account_Number,
         SUM(t.Transaction_amount) AS Transaction_Amount
  FROM BANK_ACCOUNTS_RELATIONSHIP_DETAILS r
  JOIN BANK_ACCOUNTS_RELATIONSHIP_DETAILS re ON r.Account_number = re.Linking_Account_Number AND r.Account_type = 'SAVINGS'
  JOIN BANK_ACCOUNTS_TRANSACTION t ON t.Account_Number = re.Account_Number
  WHERE re.Account_type = 'Credit Card';
''')

result=pd.read_sql_query(query,conn)
print(tabulate(result,headers='keys',tablefmt='grid'))
# Out:
# +----+------------------+-----------+----------------+--------------------------+----------------------+
# |    | Account_Number   | Account   | Account_type   | Linking_Account_Number   |   Transaction_Amount |
# +====+==================+===========+================+==========================+======================+
# |  0 | 5000-1700-9800   | SAVINGS   | Credit Card    | 5000-1700-9800           |               -15500 |
# +----+------------------+-----------+----------------+--------------------------+----------------------+
